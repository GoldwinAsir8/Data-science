# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('D:/Assignments/EDA1/EDA1/Cardiotocographic.csv')     # read the dataset from file
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data.drop('FM',axis=1,inplace=True)           # drop the column

# %%
data.drop('UC',axis=1,inplace=True)              # drop the column

# %%
data.drop('DS',axis=1,inplace=True)             # drop the column

# %%
data.drop('ALTV',axis=1,inplace=True)           # drop the column

# %%
data.drop('MLTV',axis=1,inplace=True)          # drop the column

# %%
data.drop('Width',axis=1,inplace=True)         # drop the column

# %%
data.drop('Tendency',axis=1,inplace=True)        # drop the column

# %%
data.drop('NSP',axis=1,inplace=True)           # drop the column

# %%
data                         # taken important data variables to analyze
# Out:
#               LB        AC        DL   DP  ASTV  MSTV
# 0     120.000000  0.000000  0.000000  0.0  73.0   0.5
# 1     132.000000  0.006380  0.003190  0.0  17.0   2.1
# 2     133.000000  0.003322  0.003322  0.0  16.0   2.1
# 3     134.000000  0.002561  0.002561  0.0  16.0   2.4
# 4     131.948232  0.006515  0.000000  0.0  16.0   2.4
# ...          ...       ...       ...  ...   ...   ...
# 2121  140.000000  0.000000  0.000000  0.0  79.0   0.2
# 2122  140.000000  0.000775  0.000000  0.0  78.0   0.4
# 2123  140.000000  0.000980  0.000000  0.0  79.0   0.4
# 2124  140.000000  0.000679  0.000000  0.0  78.0   0.4
# 2125  142.000000  0.001616  0.000000  0.0  74.0   0.4
#
# [2126 rows x 6 columns]

# %%
colors = ['#DE3163','#40E0D0']                            
hmap_colour=sns.color_palette(colors)                           # setting color palette to heatmap
sns.heatmap(data.isnull(), cmap = hmap_colour)                   # taken heapmap to visualize null values from the dataset
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LB      2105 non-null   float64
#  1   AC      2106 non-null   float64
#  2   DL      2126 non-null   float64
#  3   DP      2105 non-null   float64
#  4   ASTV    2126 non-null   float64
#  5   MSTV    2126 non-null   float64
# dtypes: float64(6)
# memory usage: 99.8 KB

# %%
FHR = data['LB'].mean()          # takes mean values to column variable LB

# %%
AC = data['AC'].mean()            # takes mean values to column variable AC

# %%
DP = data['DP'].mean()            # takes mean values to column variable DP

# %%
data.fillna(                                # Fill the mean values at null variables.
    {
        'LB' : FHR,
        'AC' : AC,
        'DP' : DP,
    }, inplace = True
)

# %%
data
# Out:
#               LB        AC        DL   DP  ASTV  MSTV
# 0     120.000000  0.000000  0.000000  0.0  73.0   0.5
# 1     132.000000  0.006380  0.003190  0.0  17.0   2.1
# 2     133.000000  0.003322  0.003322  0.0  16.0   2.1
# 3     134.000000  0.002561  0.002561  0.0  16.0   2.4
# 4     131.948232  0.006515  0.000000  0.0  16.0   2.4
# ...          ...       ...       ...  ...   ...   ...
# 2121  140.000000  0.000000  0.000000  0.0  79.0   0.2
# 2122  140.000000  0.000775  0.000000  0.0  78.0   0.4
# 2123  140.000000  0.000980  0.000000  0.0  79.0   0.4
# 2124  140.000000  0.000679  0.000000  0.0  78.0   0.4
# 2125  142.000000  0.001616  0.000000  0.0  74.0   0.4
#
# [2126 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LB      2126 non-null   float64
#  1   AC      2126 non-null   float64
#  2   DL      2126 non-null   float64
#  3   DP      2126 non-null   float64
#  4   ASTV    2126 non-null   float64
#  5   MSTV    2126 non-null   float64
# dtypes: float64(6)
# memory usage: 99.8 KB

# %%
data.describe()                        # describing the dataset
# Out:
#                 LB           AC           DL           DP         ASTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.001895     0.000175    46.995984
# std      11.214328     0.004370     0.003343     0.000836    18.813973
# min      51.842487    -0.019284    -0.015393    -0.005348   -63.000000
# 25%     126.000000     0.000000     0.000000     0.000000    32.000000
# 50%     133.000000     0.001668     0.000000     0.000000    49.000000
# 75%     140.000000     0.005606     0.003289     0.000000    61.000000
# max     214.000000     0.038567     0.030769     0.010695   162.000000
#
#               MSTV
# count  2126.000000
# mean      1.364378
# std       1.173632
# min      -6.600000
# 25%       0.700000
# 50%       1.200000
# 75%       1.700000
# max      13.800000

# %%
data.rename(columns={'LB':'Fetal_H_rate'},inplace=True)                 # renaming the column as Fetal_H_rate

# %%
data
# Out:
#       Fetal_H_rate        AC        DL   DP  ASTV  MSTV
# 0       120.000000  0.000000  0.000000  0.0  73.0   0.5
# 1       132.000000  0.006380  0.003190  0.0  17.0   2.1
# 2       133.000000  0.003322  0.003322  0.0  16.0   2.1
# 3       134.000000  0.002561  0.002561  0.0  16.0   2.4
# 4       131.948232  0.006515  0.000000  0.0  16.0   2.4
# ...            ...       ...       ...  ...   ...   ...
# 2121    140.000000  0.000000  0.000000  0.0  79.0   0.2
# 2122    140.000000  0.000775  0.000000  0.0  78.0   0.4
# 2123    140.000000  0.000980  0.000000  0.0  79.0   0.4
# 2124    140.000000  0.000679  0.000000  0.0  78.0   0.4
# 2125    142.000000  0.001616  0.000000  0.0  74.0   0.4
#
# [2126 rows x 6 columns]

# %%
data[data.duplicated(keep=False)]            # to visible duplicate values located in the dataset
# Out:
#       Fetal_H_rate        AC   DL   DP  ASTV  MSTV
# 67           140.0  0.007278  0.0  0.0  34.0   1.2
# 68           140.0  0.007278  0.0  0.0  34.0   1.2
# 92           148.0  0.000000  0.0  0.0  70.0   0.3
# 125          159.0  0.000000  0.0  0.0  65.0   0.4
# 128          159.0  0.000000  0.0  0.0  65.0   0.4
# ...            ...       ...  ...  ...   ...   ...
# 1812         143.0  0.000000  0.0  0.0  68.0   0.3
# 1814         143.0  0.000000  0.0  0.0  66.0   0.4
# 2061         127.0  0.000000  0.0  0.0  63.0   0.5
# 2095         133.0  0.000000  0.0  0.0  75.0   0.4
# 2096         133.0  0.000000  0.0  0.0  75.0   0.4
#
# [116 rows x 6 columns]

# %%
data.drop_duplicates(inplace=True)         # dropping the duplicate values from dataset

# %%
data
# Out:
#       Fetal_H_rate        AC        DL   DP  ASTV  MSTV
# 0       120.000000  0.000000  0.000000  0.0  73.0   0.5
# 1       132.000000  0.006380  0.003190  0.0  17.0   2.1
# 2       133.000000  0.003322  0.003322  0.0  16.0   2.1
# 3       134.000000  0.002561  0.002561  0.0  16.0   2.4
# 4       131.948232  0.006515  0.000000  0.0  16.0   2.4
# ...            ...       ...       ...  ...   ...   ...
# 2121    140.000000  0.000000  0.000000  0.0  79.0   0.2
# 2122    140.000000  0.000775  0.000000  0.0  78.0   0.4
# 2123    140.000000  0.000980  0.000000  0.0  79.0   0.4
# 2124    140.000000  0.000679  0.000000  0.0  78.0   0.4
# 2125    142.000000  0.001616  0.000000  0.0  74.0   0.4
#
# [2063 rows x 6 columns]

# %%
data.dropna(inplace=True)                      # to drop the rows which contains missing values

# %%
data.reset_index(drop=True,inplace=True)         # reset the index as per rows after drop the null rows

# %%
data
# Out:
#       Fetal_H_rate        AC        DL   DP  ASTV  MSTV
# 0       120.000000  0.000000  0.000000  0.0  73.0   0.5
# 1       132.000000  0.006380  0.003190  0.0  17.0   2.1
# 2       133.000000  0.003322  0.003322  0.0  16.0   2.1
# 3       134.000000  0.002561  0.002561  0.0  16.0   2.4
# 4       131.948232  0.006515  0.000000  0.0  16.0   2.4
# ...            ...       ...       ...  ...   ...   ...
# 2058    140.000000  0.000000  0.000000  0.0  79.0   0.2
# 2059    140.000000  0.000775  0.000000  0.0  78.0   0.4
# 2060    140.000000  0.000980  0.000000  0.0  79.0   0.4
# 2061    140.000000  0.000679  0.000000  0.0  78.0   0.4
# 2062    142.000000  0.001616  0.000000  0.0  74.0   0.4
#
# [2063 rows x 6 columns]

# %%
sns.pairplot(data, hue='Fetal_H_rate')             # pair plot to compare the variable 'Fetal heart rate' with other variables.
plt.show()

# %%
data1=data[['AC','DL','DP','ASTV','MSTV']]               # makes the dataset with certain variables
data1
# Out:
#             AC        DL   DP  ASTV  MSTV
# 0     0.000000  0.000000  0.0  73.0   0.5
# 1     0.006380  0.003190  0.0  17.0   2.1
# 2     0.003322  0.003322  0.0  16.0   2.1
# 3     0.002561  0.002561  0.0  16.0   2.4
# 4     0.006515  0.000000  0.0  16.0   2.4
# ...        ...       ...  ...   ...   ...
# 2058  0.000000  0.000000  0.0  79.0   0.2
# 2059  0.000775  0.000000  0.0  78.0   0.4
# 2060  0.000980  0.000000  0.0  79.0   0.4
# 2061  0.000679  0.000000  0.0  78.0   0.4
# 2062  0.001616  0.000000  0.0  74.0   0.4
#
# [2063 rows x 5 columns]

# %%
corr = data1.corr()             # correlation analysis between new dataset
corr
# Out:
#             AC        DL        DP      ASTV      MSTV
# AC    1.000000 -0.105699 -0.087685 -0.221041  0.121208
# DL   -0.105699  1.000000  0.141436 -0.058658  0.404001
# DP   -0.087685  0.141436  1.000000  0.044270  0.116057
# ASTV -0.221041 -0.058658  0.044270  1.000000 -0.279631
# MSTV  0.121208  0.404001  0.116057 -0.279631  1.000000

# %%
sns.heatmap(corr,cmap='BuPu', annot=True)               # made the heatmap for the correlation analysis of dataset
plt.show()

# %%
data.columns
# Out:
# Index(['Fetal_H_rate', 'AC', 'DL', 'DP', 'ASTV', 'MSTV'], dtype='object')

# %%
plt.hist(data['Fetal_H_rate'], bins=30, alpha=0.5,)
plt.hist(data['AC'], bins=30, alpha=0.5)         # plot the histogram to analyse two variables as Fetal heart rate & Acceleration to find petal well-being
plt.title('Fetal Well-being')
plt.xlabel('Fetal Heart Rate')
plt.ylabel('Acceleration')
plt.show()
